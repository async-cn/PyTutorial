# %% [markdown]
# # J5-A A+B Problem

# %% [markdown]
# 输入两个整数，输出他们的和。
#
# ## 输入格式
#
# 第一行一个整数 $a$，第二行一个整数 $b$。
#
# ## 输出格式
#
# 一行，一个整数，表示 $a+b$ 的值。
#
#
# ## 说明与提示
#
# **不要**输出任何提示信息（例如“请输入第一个数字”等），否则将被判定为WA（错误答案）
#
# 对于所有测试数据，$0\le a,b \le {10}^9$
#
# ## 执行评测
# 编写程序：[A.ipynb](A.ipynb) 或 tutorials/junior/j5/A/A.py

# %%
# !python -m pyjudge .
