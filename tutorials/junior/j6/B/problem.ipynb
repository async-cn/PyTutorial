# %% [markdown]
# # J6-B [阶梯水价](https://baike.baidu.com/item/%E9%98%B6%E6%A2%AF%E6%B0%B4%E4%BB%B7/1117325)
#
# 茂密市市长为了促进猫猫们节约用水，决定实行阶梯水价。具体规则如下：
#
# 对于每一位猫猫居民：
#
# - 用水不超过 $180 吨$ 的部分，按 $5 元/吨$ 收费；
# - 用水超过 $180 吨$ 但不超过 $400 吨$ 的部分，按 $7 元/吨$ 收费；
# - 用水超过 $400 吨$ 的部分，按 $9 元/吨$ 收费。
#
# 小猫 Maaike 这个月的总用水量为 $m$ 吨，请你帮助 Maaike 计算他这个月总计需要支付多少元的水费。
#
# ## 输入格式
#
# 一行，一个整数 $m$
#
# ## 输出格式
#
# 一行，一个整数，表示 Maaike 这个月总计需要支付的水费（元）。
#
# ## 输入输出样例
#
# ### 样例输入 #1
#
# ```text
# 210
# ```
#
# ### 样例输出 #1
#
# ```text
# 1110
# ```
#
# ### 样例输入 #2
#
# ```text
# 420
# ```
#
# ### 样例输出 #2
#
# ```text
# 2620
# ```
#
# ## 说明与提示
#
# 对于所有测试数据，$0\le m\le {10}^6$
#
# ## 执行评测
#
# 编写程序: tutorials/junior/j6/B/B.py

# %%
# !python -m pyjudge .

# %% [markdown]
# ### 小思考
#
# 已知支付的总水费，如何用 Python 程序算出总用水量？
