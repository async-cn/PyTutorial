# %% [markdown]
# # J1-B Letter H

# %% [markdown]
# 输出使用字符“*”拼成的字母“H”：
# ```text
# *   *
# *   *
# *****
# *   *
# *   *
# ```
#
# ## 输入格式
#
# 无
#
# ## 输出格式
#
# 一行，一个用字符“*”拼成的字母“H”。
#
#
# ## 说明与提示
#
# 应为 $5\times 5$ 尺寸，注意空格数量。
#
# ## 执行评测
# 编写程序：[B.ipynb](B.ipynb) 或 tutorials/junior/j1/B/B.py

# %%
# !python -m pyjudge .
