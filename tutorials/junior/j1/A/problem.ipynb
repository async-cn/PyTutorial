# %% [markdown]
# # J1-A Hello, World!

# %% [markdown]
# 输出“Hello, World!”
#
# ## 输入格式
#
# 无
#
# ## 输出格式
#
# 一行，一个字符串`Hello, World!`
#
#
# ## 说明与提示
#
# 注意大小写，[半角标点符号](https://baike.baidu.com/item/%E5%8D%8A%E8%A7%92/9323155)和空格
#
# ## 执行评测
# 编写程序: tutorials/junior/j1/A/A.py

# %%
# !python -m pyjudge .
