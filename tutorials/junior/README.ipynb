# %% [markdown]
# # 初级教程
#
# 本系列为初级教程系列，专门为为0基础的Python小白设计。
#
# 一切伟大的梦想都从一句简单的“Hello World”开始。让我们走进 Python 的世界吧！
#
# ## 教程目录
#
# - [J1 - 你好，世界！——基本输出](j1/j1.ipynb)
# - [J2 - 变量的赋值与访问](j2/j2.ipynb)
# - [J3 - 变量的命名](j3/j3.ipynb)
# - [J4 - 基本数据类型](j4/j4.ipynb)
# - [J5 - 基本输入](j5/j5.ipynb)
# - [J6 - 条件控制](j6/j6.ipynb)
# - [J7 - 比较与逻辑运算](j7/j7.ipynb)
# - [J8 - 循环语句](j8/j8.ipynb)
#
# ## 小技巧
#
# 在**终端**中输入 `python` 并按 Enter 键即可进入交互模式，在其中输入 Python 代码并回车即可立即执行并看到结果，便于进行学习探索。
#
# 搭配[b站](https://www.bilibili.com)神秘小视频辅助学习更佳。
#
# ## 为什么选择 Python？
#
# Python 的语法是极其简洁的，正如 WikiPedia 中对 Python 的描述：
#
# > Python的设计哲学，强调代码的可读性和简洁的语法，尤其是使用空格缩进来划分代码块。相比于C语言或Java，Python让开发者能够用更少的代码表达想法。
#
# 在不同的编程语言中，在控制台中输出一行“Hello, World!”需要的代码：
#
# **Python**
# ```python
# print("Hello, World!")
# ```
#
# **C++**
# ```c++
# #include <iostream>
# int main(){
#     std::cout << "Hello, World!";
#     return 0;
# }
# ```
#
# **Java**
# ```java
# public class HelloWorld {
#    public static void main(String[] args) {
#        System.out.println("Hello, World!");
#    }
# }
# ```

# %% [markdown]
# ## Hello, World!——第一个Python程序
# 试试运行以下代码：（按**Shift+Enter**运行）

# %%
print("Hello, World!")

# %% [markdown]
# 在任意目录下创建文件“hello.py”，在其中输入以上代码，保存后在其所在目录打开终端，执行命令`python hello.py`，不出意外的话就能看到一句“Hello, World!”啦~
