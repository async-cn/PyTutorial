# %% [markdown]
# # 欢迎来到 PyTutorial
#
# 本教程共包含初级、进阶、高级三个系列，选择你喜欢的系列开始吧！
#
# ## 教程目录
# - [初级教程](tutorials/junior/README.ipynb)
# - [进阶教程](tutorials/advanced/README.ipynb)
# - [高级教程](tutorials/senior/README.ipynb)
